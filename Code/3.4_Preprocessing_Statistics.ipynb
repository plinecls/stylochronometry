# %% [markdown]
# # Preprocessing the statistics (after MAT tagger was used) (see paper section 3.4)

# %%
import pandas as pd
import glob, os

# %%
pwd
# Out:
# '/Users/Documents/dta/CLS/CLS_final'

# %%
df = pd.read_csv("/Users/Documents/dta/CLS/CLS_final/chunks_1500/MAT_chunks_1500/Statistics/Statistics_chunks_1500.csv")

#

# %%
import nltk
import numpy as np
import statistics
sent_tok = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
def average_sentence_length(doc):
    sent_tok = nltk.data.load('tokenizers/punkt/english.pickle')
    
    tokenized_sentence = nltk.sent_tokenize(doc)
    
    av_sent_length = statistics.mean([len(text.split()) for text in tokenized_sentence])
    
    return round(av_sent_length, 2)

# %%
import os, glob

# %%
def get_temp_df(path):
    """Takes as argument a path to the directory containing
    chunk-txt files, and returns a dataframe with the basic information of those
    txt files - the title (filename), year, and text content - as well as the
    calculated statistic of average sentence length for each chunk.
    The returned dataframe is a temporary dataframe, made to be merged and matched up with 
    the statistics dataframe."""
    items = []

    for filename in glob.glob(path): 
        with open(filename) as f: 
            text = f.read()

        fn = os.path.basename(filename).replace(".txt", "")
        year = fn[:4]

        items.append((fn, year, text))
    
    filenames, years, texts = zip(*items)
    
    temp = pd.DataFrame({"filenames" : [tup[0] for tup in items],
                 "years": [tup[1] for tup in items],
                 "texts" : [tup[2] for tup in items]})
    
    temp.insert(3, "Average_sentence_length", temp.texts.apply(average_sentence_length))
    temp.rename(columns={"filenames":"Filename"}, inplace = True)
    
    return temp

# %%
def merge_stats_with_temp(stats, temp, merge_key):
    """Function to merge the stats dataframe with the temporary dataframe.
    Some characters such as brackets are removed from the column names, as 
    these are difficult to read by R."""
    merged_df = pd.merge(stats, temp, on=merge_key)
    merged_df.columns = merged_df.columns.str.replace(r"[\[\]]", "")
    return merged_df

# %%
path = "/Users/Documents/dta/CLS/CLS_final/chunks_1500/*.txt"

# %%
chunks_1500_temp = get_temp_df(path)

# %%
chunks_1500_temp.head()
# Out:
#             Filename years                                              texts  \
# 0  2015_manifesto-20  2015  economy, the biblical prohibition against "usu...
# 1  2015_manifesto-34  2015  merely a collective propagandist and collectiv...
# 2  2015_manifesto-35  2015  their own truth and their victory."the interna...
# 3  2015_manifesto-21  2015  in the conventional sense, because they cannot...
# 4  2015_manifesto-37  2015  to set the stage for the arrival of the crisis...
#
#    Average_sentence_length
# 0                    27.80
# 1                    23.44
# 2                    21.75
# 3                    20.28
# 4                    26.80

# %%
df.head()
# Out:
#             Filename  Tokens   AWL    TTR   AMP  ANDC  [BEMA]  [BYPA]  CAUS  \
# 0  1995_manifesto-11  1500.0  5.14  573.0  0.27   0.4    1.07    0.33  0.07
# 1  2015_manifesto-12  1501.0  5.06  549.0  0.47   0.8    1.67    0.07  0.00
# 2  2010_manifesto-12  1501.0  5.11  574.0  0.20   0.6    1.93    0.20  0.20
# 3   2010_manifesto-3  1506.0  4.89  557.0  0.13   0.6    1.93    0.07  0.27
# 4  1995_manifesto-18  1501.0  5.08  541.0  0.20   0.6    1.80    0.07  0.60
#
#    CONC  ...   VBD  VPRT  [WHCL]  [WHOBJ]  [WHQU]  [WHSUB]  [WZPAST]  \
# 0  0.00  ...  1.27  5.60    0.07     0.07    0.07     0.00      0.27
# 1  0.13  ...  1.00  5.46    0.07     0.00    0.00     0.07      0.07
# 2  0.00  ...  0.80  6.26    0.07     0.00    0.00     0.20      0.00
# 3  0.20  ...  1.00  6.44    0.00     0.13    0.00     0.13      0.00
# 4  0.00  ...  0.60  5.86    0.13     0.00    0.00     0.13      0.13
#
#    [WZPRES]   XX0  Unnamed: 69
# 0      0.00  0.67          NaN
# 1      0.07  0.53          NaN
# 2      0.20  0.47          NaN
# 3      0.20  1.13          NaN
# 4      0.13  0.53          NaN
#
# [5 rows x 70 columns]

# %%
merged_chunks_1500 = merge_stats_with_temp(df, chunks_1500_temp, "Filename")
merged_chunks_1500.head()
# Out:
# <ipython-input-13-8cc8f215d60c>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   merged_df.columns = merged_df.columns.str.replace(r"[\[\]]", "")
#             Filename  Tokens   AWL    TTR   AMP  ANDC  BEMA  BYPA  CAUS  CONC  \
# 0  1995_manifesto-11  1500.0  5.14  573.0  0.27   0.4  1.07  0.33  0.07  0.00
# 1  2015_manifesto-12  1501.0  5.06  549.0  0.47   0.8  1.67  0.07  0.00  0.13
# 2  2010_manifesto-12  1501.0  5.11  574.0  0.20   0.6  1.93  0.20  0.20  0.00
# 3   2010_manifesto-3  1506.0  4.89  557.0  0.13   0.6  1.93  0.07  0.27  0.20
# 4  1995_manifesto-18  1501.0  5.08  541.0  0.20   0.6  1.80  0.07  0.60  0.00
#
#    ...  WHOBJ  WHQU  WHSUB  WZPAST  WZPRES   XX0  Unnamed: 69  years  \
# 0  ...   0.07  0.07   0.00    0.27    0.00  0.67          NaN   1995
# 1  ...   0.00  0.00   0.07    0.07    0.07  0.53          NaN   2015
# 2  ...   0.00  0.00   0.20    0.00    0.20  0.47          NaN   2010
# 3  ...   0.13  0.00   0.13    0.00    0.20  1.13          NaN   2010
# 4  ...   0.00  0.00   0.13    0.13    0.13  0.53          NaN   1995
#
#                                                texts  Average_sentence_length
# 0  system. it is not possible to make a lasting c...                    21.43
# 1  of dangerous competition would first be establ...                    28.85
# 2  than when attempting to avoid a punishment or ...                    22.39
# 3  principles. 29. here is an illustration of the...                    21.74
# 4  and start screaming that if we fall behind in ...                    20.83
#
# [5 rows x 73 columns]

# %%
merged_chunks_1500.Filename = merged_chunks_1500.Filename.str.replace("2015", "2016")
merged_chunks_1500.insert(1, "year", [file[:4] for file in merged_chunks_1500["Filename"]])

# %%
merged_chunks_1500.head()
# Out:
#             Filename  year  Tokens   AWL    TTR   AMP  ANDC  BEMA  BYPA  CAUS  \
# 0  1995_manifesto-11  1995  1500.0  5.14  573.0  0.27   0.4  1.07  0.33  0.07
# 1  2016_manifesto-12  2016  1501.0  5.06  549.0  0.47   0.8  1.67  0.07  0.00
# 2  2010_manifesto-12  2010  1501.0  5.11  574.0  0.20   0.6  1.93  0.20  0.20
# 3   2010_manifesto-3  2010  1506.0  4.89  557.0  0.13   0.6  1.93  0.07  0.27
# 4  1995_manifesto-18  1995  1501.0  5.08  541.0  0.20   0.6  1.80  0.07  0.60
#
#    ...  WHOBJ  WHQU  WHSUB  WZPAST  WZPRES   XX0  Unnamed: 69  years  \
# 0  ...   0.07  0.07   0.00    0.27    0.00  0.67          NaN   1995
# 1  ...   0.00  0.00   0.07    0.07    0.07  0.53          NaN   2015
# 2  ...   0.00  0.00   0.20    0.00    0.20  0.47          NaN   2010
# 3  ...   0.13  0.00   0.13    0.00    0.20  1.13          NaN   2010
# 4  ...   0.00  0.00   0.13    0.13    0.13  0.53          NaN   1995
#
#                                                texts  Average_sentence_length
# 0  system. it is not possible to make a lasting c...                    21.43
# 1  of dangerous competition would first be establ...                    28.85
# 2  than when attempting to avoid a punishment or ...                    22.39
# 3  principles. 29. here is an illustration of the...                    21.74
# 4  and start screaming that if we fall behind in ...                    20.83
#
# [5 rows x 74 columns]

# %%
merged_chunks_1500.to_csv("chunks_1500/chunks_1500_stats.csv", sep=",", encoding="utf8", index=False)

# %%
pwd
# Out:
# '/Users/Documents/dta/CLS/CLS_final'
